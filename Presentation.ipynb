# %% [markdown]
# # <center> __FE538 TEAM PROJECT PRESENTATION__ </center>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# #### <div class="pull-right">_Presentor &nbsp;&nbsp; 이광현&nbsp; &nbsp; &nbsp; &nbsp; &nbsp;_</div>
# #### <div class="pull-right">_&nbsp;&nbsp; 곽지훈 &nbsp; 장지은 &nbsp; 이광현&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;_</div>
#
# ---
#
# <br>
#
# # <center>__CONTENTS &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;__</center>
#
# <br>
# <br>
#
# #### <center>I. Backtestig module &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; </center>
# #### <center>II. Backtesting Analysis module &nbsp; &nbsp;</center>
# #### <center>III. Improving Strategy module &nbsp; &nbsp; &nbsp;  </center>
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# ---

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# <br>
# <br>
#
# ### __I. Backtesting Module__
#
# ---

# %% [markdown]
# <br>
# <br>
#
# ### __II. Backtesting Analysis Module__
#
# ---

# %%
from backtesting_analyzer import *
# %matplotlib inline
# Out:
# * Data Loading
# 	 File loading...  complete!! 2.30032 sec.
# 	 File unpacking...  complete!! 1.02724 sec.
#
# * Backtesting - Invest class generating
# 	 Sample investment generating
# 		 Sample with cost
# 		 ------------ daily_strategy01 ------------
# 		 Activate success!!
# 		 Backtesting success!!
# 		 Expansion success!!
# 		 Performance analysis success!!
# 		 --------------- Generate!! ---------------
#
# * Backtesting - Invest class generating
# 	 Sample investment generating
# 		 Sample without cost
# 		 ------------ daily_strategy01 ------------
# 		 Activate success!!
# 		 Backtesting success!!
# 		 Expansion success!!
# 		 Performance analysis success!!
# 		 --------------- Generate!! ---------------

# %%
invest = backtest('QVM_SD_6w121.pkl', 100000000, fee_rate=0., tax_rate=0.)
# Out:
# * Backtesting - Invest class generating
# 	 QVM_SD_6w121.pkl is external file!
# 	 Attempting to read QVM_SD_6w121.pkl in strategy folder...  Success!
#
# 		 ------------ QVM_SD_6w121 ------------
# 		 Activate success!!
# 		 Backtesting success!!
# 		 Expansion success!!
# 		 Performance analysis success!!
# 		 --------------- Generate!! ---------------

# %% [markdown]
# <br>
# <br>
#
# ### __III. Improving Strategy Module__
#
# ---

# %%
invest_analyze = Analyzer(invest)
invest_analyze.activate()

# %%
invest_analyze.rebal.show()
# Out:
# Correlation of Portfolio Performance and Benchmark
#                  relative_return  benchmark
# relative_return         1.000000  -0.015074
# benchmark              -0.015074   1.000000
#
#
# Correlation of Win Portfolio Performance and Benchmark
#                  relative_return  benchmark
# relative_return         1.000000   0.521783
# benchmark               0.521783   1.000000
#
#
# Correlation of Lose Portfolio Performance and Benchmark
#                  relative_return  benchmark
# relative_return         1.000000  -0.150241
# benchmark              -0.150241   1.000000

# %%
invest_analyze.rebal

# %%
r.porf_lose
# Out:
#                       return  return_relative
# 2008-10-01 A001430 -0.270321         0.058054
#            A053610 -0.213130         0.115245
#            A069510 -0.501639        -0.173264
#            total   -0.328375        -0.112638
# 2009-01-02 A069510 -0.238462         0.000000
#            total   -0.238462        -0.229433
# 2009-06-01 A069510 -0.181287         0.000000
#            total   -0.181287        -0.178856
# 2011-05-02 A012630 -0.088212         0.074291
#            A095340 -0.236794        -0.074292
#            total   -0.162503        -0.123193
# 2011-09-01 A012630 -0.391378        -0.147808
#            A095340 -0.095827         0.147743
#            total   -0.243570        -0.150780
# 2012-12-03 A013120 -0.068273        -0.004487
#            A071320 -0.113553        -0.049767
#            A095340 -0.009535         0.054252
#            total   -0.063786        -0.110734
# 2013-11-01 A013120 -0.096317         0.022030
# ...

# %%
x = (pd.concat([pd.Series((r.test.loc[r.win_dates[0]]).dropna(), name='return'), pd.Series(r.test2.loc[r.win_dates[0]].dropna(), name='return_relative')], axis=1))
x.loc['total'] = np.array(r.perf[['return', 'relative_return']].loc[r.win_dates[0]])
x.index = pd.MultiIndex.from_product([[r.win_dates[0]], x.index])
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-30774b23ba0e> in <module>
#       1 x = (pd.concat([pd.Series((r.test.loc[r.win_dates[0]]).dropna(), name='return'), pd.Series(r.test2.loc[r.win_dates[0]].dropna(), name='return_relative')], axis=1))
#       2 x.loc['total'] = np.array(r.perf[['return', 'relative_return']].loc[r.win_dates[0]])
# ----> 3 x.index = pd.MultiIndex.from_product([list(r.win_dates[0]), x.index])
#       4 x
#
# TypeError: 'Timestamp' object is not iterable
